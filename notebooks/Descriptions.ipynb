# %%
import pandas as pd

# %%
auctions = pd.read_json('../descriptions/auctions.json')

# %%
auctions.T
# Out:
#                                                      desc  transformation
# auction_type_id                           type of auction            None
# country          country where the auction was originated  string hashing
# date                                 date for the auction            None
# device_id                    device the auction came from  string hashing
# platform                                     android, ios            None
# ref_type_id                 internal id for the ref_typew            None
# source_id         source (exchange) the auction came from   LabelEncoding

# %%
clicks = pd.read_json('../descriptions/clicks.json')

# %%
clicks.T
# Out:
#                                                               desc  \
# advertiser_id    internal id for the advertiser, Jampp's client...
# action_id                                internal id for an action
# source_id        internal id for the source (exchange) from whi...
# created                                creation time for the click
# country_code                              internal country code id
# latitude               estimated lat where the click was performed
# longitude             estimated lon where then click was performed
# wifi_connection  Boolean describing whether the click was perfo...
# carrier_id                 Id for the mobile carrier of the device
# trans_id                                   internal transaction id
# os_minor                                  minor version for the OS
# agent_device     agent for the device the click was performed o...
# os_major                                  major version for the os
# specs_brand
# ...

# %%
events = pd.read_json('../descriptions/events.json')

# %%
events.T
# Out:
#                                                                  desc  \
# application_id      internal id for the event on which the event w...
# attributed                  whether the event was attributed to Jampp
# carrier                                       device's mobile carrier
# connection_type
# date                                date when the event was performed
# device_brand                                           device's brand
# device_city               inferred city where the event was performed
# device_countrycode                 country code related to the device
# device_language                        language related to the device
# device_model                                           device's model
# device_os                                       os used by the device
# device_os_version                       os version used by the device
# event_id                                   id generated for the event
# ...

# %%
installs = pd.read_json('../descriptions/installs.json')

# %%
installs.T
# Out:
#                                                                  desc  \
# application_id                      internal id for the installed app
# attributed                whether the install was attributed to Jampp
# click_hash                          hash for the install (like an id)
# created                                 creation date for the install
# device_brand                                           device's brand
# device_countrycode                        country code for the device
# device_language                        language related to the device
# device_model                                           device's model
# event_uuid                              uuid4 generated for the event
# implicit            whether the install is implicit (the install w...
# ip_address          ip addres through which the install was performed
# kind                                                  kind of install
# ...
